# %% [markdown]
# # 2022 — Diffusion Steganography — Channel Analysis
#
# Compares payload survival across re-encoding channels. The LSB baseline is high-capacity but fragile; diffusion-stego trades capacity for robustness; ECC narrows the gap.

# %%
import json, matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## JPEG survival

# %%
from IPython.display import Image
Image('figures/jpeg_survival.png')
# Out:
# <Figure (see figures/jpeg_survival.png)>

# %% [markdown]
# ## Capacity comparison

# %%
Image('figures/capacity_comparison.png')
# Out:
# <Figure (see figures/capacity_comparison.png)>

# %% [markdown]
# LSB has ~3000× the capacity but is detectable and fragile. Diffusion-stego trades capacity for plausibility — kilobits survive, megabits don't fit.

# %% [markdown]
# ## Detectability vs payload density

# %%
Image('figures/detection_rate.png')
# Out:
# <Figure (see figures/detection_rate.png)>

# %% [markdown]
# **Takeaway:** for small payloads where the cover image must look natural, diffusion-stego + RS ECC is the right tool. For high-bandwidth covert channels, use a different primitive.
